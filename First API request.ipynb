# %%
import pandas as pd

# %%
# !pip install jsonschema

# %%
# !pip install requests

# %%
import requests

# %%
response = requests.get("https://data.covid19.go.id/public/api/prov.json")

# %%
print(response.status_code)
# Out:
# 200

# %%
df = pd.read_json('https://data.covid19.go.id/public/api/prov.json')

# %%
df.head(100)
# Out:
#      last_date  current_data  missing_data  tanpa_provinsi  \
# 0   2020-11-23     99.994745      0.005255              23
# 1   2020-11-23     99.994745      0.005255              23
# 2   2020-11-23     99.994745      0.005255              23
# 3   2020-11-23     99.994745      0.005255              23
# 4   2020-11-23     99.994745      0.005255              23
# 5   2020-11-23     99.994745      0.005255              23
# 6   2020-11-23     99.994745      0.005255              23
# 7   2020-11-23     99.994745      0.005255              23
# 8   2020-11-23     99.994745      0.005255              23
# 9   2020-11-23     99.994745      0.005255              23
# 10  2020-11-23     99.994745      0.005255              23
# 11  2020-11-23     99.994745      0.005255              23
# 12  2020-11-23     99.994745      0.005255              23
# 13  2020-11-23     99.994745      0.005255              23
# 14  2020-11-23     99.994745      0.005255              23
# ...

# %%
dict{'list_data'}
# Out:
#   File "<ipython-input-20-e6b0dbb34e22>", line 1
#     dict{'list_data'}
#         ^
# SyntaxError: invalid syntax
